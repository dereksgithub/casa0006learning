# %% [markdown]
# # CASA0006 Practical 3: Tree-based methods
# ## 0.1 Import Libs and Data Overview

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import sklearn
from sklearn.model_selection import train_test_split, GridSearchCV, validation_curve
from sklearn.metrics import mean_squared_error

# CART
from sklearn.tree import DecisionTreeRegressor

# random forest
from sklearn.ensemble import RandomForestRegressor

# feature importance
import rfpimp

# xgboost
import xgboost
from xgboost import XGBRegressor

pd.set_option('display.max_rows', 300) # specifies number of rows to show
pd.options.display.float_format = '{:40,.4f}'.format # specifies default number format to 4 decimal places
plt.style.use('ggplot') # specifies that graphs should use ggplot styling
# %matplotlib inline

# %% [markdown]
# check the library version before we start

# %%
print("xgboost version:{}".format(xgboost.__version__))
print("sklearn version:{}".format(sklearn.__version__))
# Out:
# xgboost version:2.0.3
# sklearn version:1.3.2

# %% [markdown]
# Data Loading and Exploration
#
# The dataset you will use relates to daily counts of rented bicycles from the bicycle rental company Capital-Bikeshare in Washington D.C., along with weather and seasonal information. The goal here is to predict how many bikes will be rented depending on the weather and the day. The original data can be downloaded from the UCI Machine Learning Repository.
#
# The dataset used in this workshop has been slightly processed by Christoph Molnar using the processing R-script from this Github repository. Here, the dataset is provided as a csv file on Moodle.
#
# Here is a list of the variables in the dataset:
#
# - Count of bicycles including both casual and registered users. The count is used as the response in the regression task.
# - Indicator of the season, either spring, summer, fall or winter.
# - Indicator whether the day was a holiday or not.
# - The year: either 2011 or 2012.
# - Number of days since the 01.01.2011 (the first day in the dataset). This predictor was introduced to take account of the trend over time.
# - Indicator whether the day was a working day or weekend.
# - The weather situation on that day. One of:
#     - 'GOOD': including clear, few clouds, partly cloudy, cloudy
#     - 'MISTY': including mist + clouds, mist + broken clouds, mist + few clouds, mist
#     - 'RAIN/SNOW/STORM': including light snow, light rain + thunderstorm + scattered clouds, light rain + scattered clouds, heavy rain + ice pallets + thunderstorm + mist, snow + mist
# - Temperature in degrees Celsius.
# - Relative humidity in percent (0 to 100).
# - Wind speed in km/h.
#
# We will use Pandas package to load and explore this dataset:
#
# - Import the Boston housing dataset as a Pandas dataframe (call it bike_rental)
# - Inspect the data
# - Calculate summary statistics on all attributes

# %%
bike_rental = pd.read_csv('https://raw.githubusercontent.com/huanfachen/Spatial_Data_Science/main/Dataset/daily_count_bike_rental.csv')
# drop the year variable as it is not useful
bike_rental = bike_rental.drop(['yr'], axis=1)

# %%
bike_rental.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cnt              731 non-null    int64
#  1   season           731 non-null    object
#  2   mnth             731 non-null    object
#  3   holiday          731 non-null    object
#  4   weekday          731 non-null    object
#  5   workingday       731 non-null    object
#  6   weathersit       731 non-null    object
#  7   temp             731 non-null    float64
#  8   hum              731 non-null    float64
#  9   windspeed        731 non-null    float64
#  10  days_since_2011  731 non-null    int64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 62.9+ KB

# %% [markdown]
# ## 0.2 DIY Bootstrap Test:

# %% [markdown]
# In bike_rental, there are two data types: categorical (aka object), and numerical (including int64 and float64).

# %%
# print a few rows of this dataset
bike_rental.head()
# Out:
#     cnt  season mnth     holiday weekday      workingday weathersit  \
# 0   985  SPRING  JAN  NO HOLIDAY     SAT  NO WORKING DAY      MISTY
# 1   801  SPRING  JAN  NO HOLIDAY     SUN  NO WORKING DAY      MISTY
# 2  1349  SPRING  JAN  NO HOLIDAY     MON     WORKING DAY       GOOD
# 3  1562  SPRING  JAN  NO HOLIDAY     TUE     WORKING DAY       GOOD
# 4  1600  SPRING  JAN  NO HOLIDAY     WED     WORKING DAY       GOOD
#
#                                       temp  \
# 0                                   8.1758
# 1                                   9.0835
# 2                                   1.2291
# 3                                   1.4000
# 4                                   2.6670
#
#                                        hum  \
# 0                                  80.5833
# 1                                  69.6087
# 2                                  43.7273
# 3                                  59.0435
# 4                                  43.6957
#
#                                  windspeed  days_since_2011
# 0                                  10.7499                0
# 1                                  16.6521                1
# 2                                  16.6367                2
# 3                                  10.7398                3
# 4                                  12.5223                4

# %% [markdown]
# Converting categorical variables
#
# Before undertaking regression, we need to handle categorical variables, as ML models usually can't deal with strings or categories.
#
# While there are other ways of handling categorical variables in machine learning, we will stick to one-hot encoding, as it is easy to understand and appropriate for medium-size datasets (sample size <10000).
#
# First, we need to convert categorical variables into dummy/indicator variables, using **One-Hot Encoding.**

# %%
bike_rentail_numeric = pd.get_dummies(bike_rental)

bike_rentail_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   cnt                         731 non-null    int64
#  1   temp                        731 non-null    float64
#  2   hum                         731 non-null    float64
#  3   windspeed                   731 non-null    float64
#  4   days_since_2011             731 non-null    int64
#  5   season_FALL                 731 non-null    bool
#  6   season_SPRING               731 non-null    bool
#  7   season_SUMMER               731 non-null    bool
#  8   season_WINTER               731 non-null    bool
#  9   mnth_APR                    731 non-null    bool
#  10  mnth_AUG                    731 non-null    bool
#  11  mnth_DEZ                    731 non-null    bool
#  12  mnth_FEB                    731 non-null    bool
#  13  mnth_JAN                    731 non-null    bool
#  14  mnth_JUL                    731 non-null    bool
#  15  mnth_JUN                    731 non-null    bool
#  16  mnth_MAR                    731 non-null    bool
#  17  mnth_MAY                    731 non-null    bool
#  18  mnth_NOV                    731 non-null    bool
#  19  mnth_OKT                    731 non-null    bool
#  20  mnth_SEP                    731 non-null    bool
#  21  holiday_HOLIDAY             731 non-null    bool
#  22  holiday_NO HOLIDAY          731 non-null    bool
#  23  weekday_FRI                 731 non-null    bool
#  24  weekday_MON                 731 non-null    bool
#  25  weekday_SAT                 731 non-null    bool
#  26  weekday_SUN                 731 non-null    bool
#  27  weekday_THU                 731 non-null    bool
#  28  weekday_TUE                 731 non-null    bool
#  29  weekday_WED                 731 non-null    bool
#  30  workingday_NO WORKING DAY   731 non-null    bool
#  31  workingday_WORKING DAY      731 non-null    bool
#  32  weathersit_GOOD             731 non-null    bool
#  33  weathersit_MISTY            731 non-null    bool
#  34  weathersit_RAIN/SNOW/STORM  731 non-null    bool
# dtypes: bool(30), float64(3), int64(2)
# memory usage: 50.1 KB

# %%
bike_rental_final = bike_rentail_numeric.drop(['season_SPRING', 'mnth_JAN', 'holiday_NO HOLIDAY', 'weekday_MON', 'workingday_WORKING DAY', 'weathersit_GOOD'], axis=1)

# double check the result
bike_rental_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   cnt                         731 non-null    int64
#  1   temp                        731 non-null    float64
#  2   hum                         731 non-null    float64
#  3   windspeed                   731 non-null    float64
#  4   days_since_2011             731 non-null    int64
#  5   season_FALL                 731 non-null    bool
#  6   season_SUMMER               731 non-null    bool
#  7   season_WINTER               731 non-null    bool
#  8   mnth_APR                    731 non-null    bool
#  9   mnth_AUG                    731 non-null    bool
#  10  mnth_DEZ                    731 non-null    bool
#  11  mnth_FEB                    731 non-null    bool
#  12  mnth_JUL                    731 non-null    bool
#  13  mnth_JUN                    731 non-null    bool
#  14  mnth_MAR                    731 non-null    bool
#  15  mnth_MAY                    731 non-null    bool
#  16  mnth_NOV                    731 non-null    bool
#  17  mnth_OKT                    731 non-null    bool
#  18  mnth_SEP                    731 non-null    bool
#  19  holiday_HOLIDAY             731 non-null    bool
#  20  weekday_FRI                 731 non-null    bool
#  21  weekday_SAT                 731 non-null    bool
#  22  weekday_SUN                 731 non-null    bool
#  23  weekday_THU                 731 non-null    bool
#  24  weekday_TUE                 731 non-null    bool
#  25  weekday_WED                 731 non-null    bool
#  26  workingday_NO WORKING DAY   731 non-null    bool
#  27  weathersit_MISTY            731 non-null    bool
#  28  weathersit_RAIN/SNOW/STORM  731 non-null    bool
# dtypes: bool(24), float64(3), int64(2)
# memory usage: 45.8 KB

# %% [markdown]
# Splitting data into random train and test subsets
#
# By default, train_test_split will split the data according to a 75:25 split. Other proportions can be specified, check out the documentation for details.
#
# Remember that the split should be random in order to avoid selection bias. Here, we set random_state=100 to guarantee reproducibility.
#
# From the documentation:
#
# The first argument of this function:
#
# *arrays: sequence of indexables with same length / shape[0]
# Allowed inputs are lists, numpy arrays, scipy-sparse matrices or pandas dataframes.
#
# The output of this function:
#
# splitting: list, length=2 * len(arrays)
# List containing train-test split of inputs.
#
# Here we input two dataframes (X and Y) and will get four outputs (train_x, test_x, train_y, test_y).
#
# ## 1.1 Decision Tree

# %%
random_state_split = 100
train_x, test_x, train_y, test_y = train_test_split(bike_rental_final.drop(['cnt'], axis = 1), bike_rental_final.cnt, random_state=random_state_split)

# %%
print(train_x.shape)
print(train_y.shape)
print(test_x.shape)
print(test_y.shape)

# check the index of train_x and train_y - they should be identical. The index indicates which rows from the original data.

print(train_x.index.identical(train_y.index))
print(test_x.index.identical(test_y.index))
# Out:
# (548, 28)
# (548,)
# (183, 28)
# (183,)
# True
# True

# %% [markdown]
# In the regression models, we will use the training set to train the model and select hyperparameters. The testing set is only used to report the performance of the finalised model.
# Building a CART
#
# We will build a CART to predict the bicycle rental, following two steps:
#
#     Tune the hyperparameters of max_depth and min_samples_split using cross validation;
#     Train a final model based on the tuned hyperparameters and evaluate the model performance.
#
# Here, we focus on two hyperparameters that control the stopping criteria of the model training: max_depth and min_samples_split.
#
# max_depth refers to the maximal depth (or height) of a tree. In sklearn, if this value is not specified, the nodes would be expanded until all leaves contain samples of the same y value or until all leaves contain less than min_samples_split samples.
#
# Intuition about max_depth: the larger the maximum tree depth, the better fitness of the model on the training data and thus the higher possibility of overfitting.
#
# Ideally, we want the maximum tree height to be neither too small or too large.
#
# The documentation is as follows:
#
# max_depth: int, default=None
# The maximum depth of the tree. If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split samples.
#
# min_samples_split refers to the minimum number of samples required to split a node. If a node contains less samples than min_samples_split, this node becomes a leaf node and would not split.
#
# The smaller value of min_samples_split, the better fitness of the model and thus the higher possibility of overfitting.
#
# The documentation is as follows (note that the value can be either integer or float, but the meaning is different)
#
# min_samples_split: int or float, default=2
# The minimum number of samples required to split an internal node:
#
# If int, then consider min_samples_split as the minimum number.
#
# If float, then min_samples_split is a fraction and ceil(min_samples_split * n_samples) are the minimum number of samples for each split.
#
# Tuning the hyperparameters using cross validation
#
# We will use GridSearchCV to find the optimal combination of max_depth and min_samples_split.
#
# Note that in grid search, all combinations of hyperparameters will be tested and compared. In this case, 25 (5*5) different combinations of hyperparameters will be tested.
#
# One question - how to determine the potential values of max_depth and min_samples_split?
#
# For min_samples_split, as it is a positive integer value and the default value is 2, we can set the range as [2,4,6,8,10].
#
# For max_depth, we can build a decision tree using default settings and check the tree depth, then choose the range around this tree depth.
#
# The code below shows that the tree depth of a CART with default settings is 25, so we can set the range as [10,20,30,40,50].

# %%
# a CART using default settings
cart_default = DecisionTreeRegressor(random_state=0)
cart_default.fit(train_x, train_y)
# print the tree depth
print("Tree depth: {}".format(cart_default.get_depth()))
# Out:
# Tree depth: 25

# %%
# values of max_depth and min_samples_split
hyperparameters = {'max_depth':[10,20,30,40,50], 'min_samples_split':[2,4,6,8,10]}

randomState_dt = 10000
dt = DecisionTreeRegressor(random_state=randomState_dt)

# cv=5 by default, which means 5-fold cross-validation
clf = GridSearchCV(dt, hyperparameters)

clf.fit(train_x, train_y)

# we can query the best parameter value and its accuracy score
print ("The best parameter value is: ")
print (clf.best_params_)
print ("The best score is: ")
print (clf.best_score_)
# Out:
# The best parameter value is:
# {'max_depth': 10, 'min_samples_split': 8}
# The best score is:
# 0.7549920033546205

# %% [markdown]
# Training the final CART

# %%
dt_final = DecisionTreeRegressor(max_depth=clf.best_params_['max_depth'], min_samples_split=clf.best_params_['min_samples_split'], random_state=randomState_dt)
dt_final.fit(train_x, train_y)
# Out:
# DecisionTreeRegressor(max_depth=10, min_samples_split=8, random_state=10000)

# %%
print("R2 on the training data:")
print(dt_final.score(X=train_x, y=train_y))
print("R2 on the testing data:")
print(dt_final.score(X=test_x, y=test_y))
# Out:
# R2 on the training data:
# 0.9727089518051003
# R2 on the testing data:
# 0.757715812742848

# %%
print("RMSE on the training data:")
print(mean_squared_error(train_y, dt_final.predict(train_x), squared=False))
print("RMSE on the testing data:")
print(mean_squared_error(test_y, dt_final.predict(test_x), squared=False))
# Out:
# RMSE on the training data:
# 322.91814665797057
# RMSE on the testing data:
# 922.8954973299212

# %% [markdown]
# The RMSE is in the same unit of the y variable (bicycle rental). On the testing data, on average, the model's prediction deviates from the true bicycle rental by 922.
#
# If you want to know the relative error, you can compute the normalised RMSE by dividing the mean true value, as follows:

# %%
print("Normalised RMSE on the training data:")
print(mean_squared_error(train_y, dt_final.predict(train_x), squared=False)/np.mean(train_y))
print("Normalised RMSE on the testing data:")
print(mean_squared_error(test_y, dt_final.predict(test_x), squared=False)/np.mean(test_y))
# Out:
# Normalised RMSE on the training data:
# 0.0722168443537336
# Normalised RMSE on the testing data:
# 0.2005120261136868

# %% [markdown]
# Interpreting the CART

# %%
# some attributes of the tree
print("Tree depth:{}".format(dt_final.get_depth()))
print("Number of leaves:{}".format(dt_final.get_n_leaves()))
# Out:
# Tree depth:10
# Number of leaves:114

# %% [markdown]
# There are different ways to inspect and interpret the CART.
#
# One way is to visualise the whole tree and check each node and split. However, this is not easy for a tree with 10 layers and over 100 leaves.
#
# Another way is to check the relative importance of each feature, for example, using the permutation feature importance.
#
# To do this, we will use the rfpimp package.
#
# rfpimp is short for random forest permutation importance. It is a library that provides feature importances, based upon the permutation importance strategy, for general scikit-learn models and implementations specifically for random forest out-of-bag scores. Built by Terence Parr and Kerem Turgutlu.
#
# We will use the rfpimp.importances function to compute the feature importance. According to its documentation:
#
# Compute permutation feature importances for scikit-learn models using a validation set.
# Given a Classifier or Regressor in model and validation X and y data, return a data frame with columns.
# Feature and Importance sorted in reverse order by importance.
# The validation data is needed to compute model performance measures (accuracy or R^2). The model is not retrained.
#
# So the importance of a feature x is defined as the difference of the R^2 model score (computed by dt_final.score()) after shuffling x and without shuffling x.
#
# The feature importance is mostly positive or a negative value very close to zero, as shuffling a feature is not expected to greatly improve the model performance.
#
# The feature importance is usually used to compare the relative importance of features. It is not recommended to interpret the absolute value of this importance.

# %%
# the importances function returns a dataframe of two columns, Feature and Importance, and the features are ranked from the most important to the least.
imp = rfpimp.importances(dt_final, test_x, test_y)
print(imp)
# Out:
#                                                          Importance
# Feature
# days_since_2011                                              0.9663
# temp                                                         0.4974
# hum                                                          0.0598
# weathersit_RAIN/SNOW/STORM                                   0.0132
# windspeed                                                    0.0131
# weekday_SAT                                                  0.0107
# mnth_JUN                                                     0.0089
# weekday_WED                                                  0.0072
# weekday_TUE                                                  0.0019
# mnth_OKT                                                     0.0012
# holiday_HOLIDAY                                              0.0008
# season_SUMMER                                                0.0000
# weekday_SUN                                                  0.0000
# weekday_FRI                                                  0.0000
# mnth_SEP                                                     0.0000
# season_FALL                                                  0.0000
# mnth_NOV                                                     0.0000
# mnth_MAR                                                     0.0000
# mnth_FEB                                                     0.0000
# mnth_DEZ                                                     0.0000
# mnth_AUG                                                     0.0000
# season_WINTER                                                0.0000
# mnth_MAY                                                     0.0000
# mnth_JUL                                                    -0.0004
# workingday_NO WORKING DAY                                   -0.0005
# weekday_THU                                                 -0.0030
# mnth_APR                                                    -0.0054
# weathersit_MISTY                                            -0.0206

# %%
## Here is a barplot of the feature importance
viz = rfpimp.plot_importances(imp)
viz.view()

# %% [markdown]
# ## 2.1 Building and interpreting a random forest
#
# In this part, we will use the random forest method to predict the daily bicycle rental. We will follow a simple workflow as CART: tune the hyperparameters and then train the final model.
#
# RF has two groups of hyperparameters:
#
#     The hyperparameters of decision trees, such as max_depth, min_samples_split;
#     The configurations of RF, such as the number of trees (called n_estimators). By default, n_estimators is set as 100. Some intuition is that the larger n_estimators, the more stable the model performance and the longer computing time. This is because the computing time is a linear function of the number of trees.
#
# The default value of 100 trees is good for most applications, so we don't tune this hyperparameter here.
#
# As with CART, we will focus on the tuning of max_depth and min_samples_split.

# %%
# values of max_depth and min_samples_split
hyperparameters = {'max_depth':[10,20,30,40,50], 'min_samples_split':[2,4,6,8,10]}

randomState_dt = 10000
rf = RandomForestRegressor(random_state=randomState_dt)

# cv=5 by default, which means 5-fold cross-validation
clf = GridSearchCV(rf, hyperparameters)

clf.fit(train_x, train_y)

# we can query the best parameter value and its accuracy score
print ("The best parameter value is: ")
print (clf.best_params_)
print ("The best score is: ")
print (clf.best_score_)
# Out:
# The best parameter value is:
# {'max_depth': 30, 'min_samples_split': 2}
# The best score is:
# 0.8594678489298346

# %%
rf_final = RandomForestRegressor(max_depth=clf.best_params_['max_depth'], min_samples_split=clf.best_params_['min_samples_split'], random_state=randomState_dt)
rf_final.fit(train_x, train_y)
# Out:
# RandomForestRegressor(max_depth=30, random_state=10000)

# %%
print("R2 on the training data:")
print(rf_final.score(X=train_x, y=train_y))
print("R2 on the testing data:")
print(rf_final.score(X=test_x, y=test_y))
# Out:
# R2 on the training data:
# 0.9818090978256703
# R2 on the testing data:
# 0.883608777650514

# %%
#mse_scores = -scores

# Calculate RMSE for each fold
#rmse_scores = np.sqrt(mse_scores)
print("RMSE on the training data:")

print(mean_squared_error(train_y, rf_final.predict(train_x), squared=False))
print("RMSE on the testing data:")
print(mean_squared_error(test_y, rf_final.predict(test_x), squared=False))
# Out:
# RMSE on the training data:
# 263.63888257826613
# RMSE on the testing data:
# 639.6613442103948

# %%
imp = rfpimp.importances(rf_final, test_x, test_y)
print(imp)
viz = rfpimp.plot_importances(imp)
viz.view()
# Out:
#                                                          Importance
# Feature
# days_since_2011                                              0.8465
# temp                                                         0.4803
# hum                                                          0.0706
# windspeed                                                    0.0176
# weathersit_RAIN/SNOW/STORM                                   0.0039
# workingday_NO WORKING DAY                                    0.0032
# weekday_SUN                                                  0.0031
# weekday_SAT                                                  0.0024
# season_WINTER                                                0.0024
# weathersit_MISTY                                             0.0024
# weekday_FRI                                                  0.0019
# holiday_HOLIDAY                                              0.0018
# mnth_DEZ                                                     0.0013
# mnth_SEP                                                     0.0009
# mnth_OKT                                                     0.0009
# mnth_APR                                                     0.0004
# season_SUMMER                                                0.0004
# weekday_WED                                                  0.0003
# mnth_NOV                                                     0.0003
# mnth_FEB                                                     0.0001
# mnth_JUN                                                     0.0000
# mnth_JUL                                                    -0.0000
# mnth_MAR                                                    -0.0000
# mnth_AUG                                                    -0.0001
# weekday_TUE                                                 -0.0002
# season_FALL                                                 -0.0003
# mnth_MAY                                                    -0.0005
# weekday_THU                                                 -0.0006

# %% [markdown]
# ## 2.2 Plotting RF Metrics

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor

# Assuming rf_final is your trained RandomForestRegressor and test_x is your test data
# Initialize an empty matrix for the proximity matrix
proximity_matrix = np.zeros((test_x.shape[0], test_x.shape[0]))

# Populate the proximity matrix
for tree in rf_final.estimators_:
    leaf_indices = tree.apply(test_x)
    for i in range(test_x.shape[0]):
        for j in range(test_x.shape[0]):
            if leaf_indices[i] == leaf_indices[j]:
                proximity_matrix[i, j] += 1

# Normalize the proximity matrix
proximity_matrix = proximity_matrix / rf_final.n_estimators

# Now, you can calculate the distance matrix as the inverse of the proximity matrix
# or use any other suitable method
# Here we use 1 - proximity as a simple approach
distance_matrix = 1 - proximity_matrix

# Plot the distance matrix
import matplotlib.pyplot as plt
plt.imshow(distance_matrix, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.title('Distance Matrix')
plt.show()
# Out:
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/base.py:458: UserWarning: X has feature names, but DecisionTreeRegressor was fitted without feature names
#   warnings.warn(

# %%
import matplotlib.pyplot as plt

# Assuming proximity_matrix is your proximity matrix
plt.imshow(proximity_matrix, cmap='hot', interpolation='nearest')
plt.colorbar()
plt.title('Proximity Matrix Heatmap')
plt.show()

# %%
import numpy as np
from sklearn.manifold import MDS
import matplotlib.pyplot as plt
## mds plot:
# Assuming distance_matrix is your distance matrix
embedding = MDS(n_components=2, dissimilarity='precomputed')
X_transformed = embedding.fit_transform(distance_matrix)
plt.scatter(X_transformed[:,0], X_transformed[:,1])
plt.title('MDS Plot')
plt.show()
# Out:
# /home/mengyuwsl/.local/lib/python3.10/site-packages/sklearn/manifold/_mds.py:298: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %% [markdown]
# ## 2.3 Interpretin the MDS Plot:
# From this MDS plot:
# 1. Data points are quite homogeneous
# 2. However, this may indicate that RF regressor did not find out clear distinctions between the data.

# %% [markdown]
# ## 3. Building and interpreting a XGBoost
#
# In this part, we will use the XGBoost method to predict the daily bicycle rental. We will follow a simple workflow as CART and RF: tune the hyperparameters and then train the final model.
#
# XGBoost is not part of the sklearn library but a separate library. It provides the sklearn API so that we can use XGboost in the same way as RandomForestRegressor of sklearn.
#
# XGBoost has two groups of hyperparameters:
#
#     The hyperparameters of decision trees, such as max_depth, min_samples_split;
#     The configurations of XGBoost, such as the number of trees (called n_estimators) and regularisation hyperparameters.
#
# Here are a list of potentially important hyperparameters for XGBoost, recommended by this post:
#
#     max_depth: The maximum depth per tree. A deeper tree might increase the performance, but also the complexity and chances to overfit. The value must be an integer greater than 0. Default is 6.
#
#     learning_rate: The learning rate determines the step size at each iteration while your model optimizes toward its objective. A low learning rate makes computation slower, and requires more rounds to achieve the same reduction in residual error as a model with a high learning rate. But it optimizes the chances to reach the best optimum. The value must be between 0 and 1. Default is 0.3.
#
#     n_estimators: The number of trees in the ensemble. Equivalent to the number of boosting rounds. The value must be an integer greater than 0. Default is 100.
#
#     colsample_bytree: Represents the fraction of columns to be randomly sampled for each tree. It might improve overfitting.
#
# The value must be between 0 and 1. Default is 1.
#
#     subsample: Represents the fraction of observations to be sampled for each tree. A lower values prevent overfitting but might lead to under-fitting.
#
# The value must be between 0 and 1. Default is 1.
#
#     alpha (reg_alpha): L1 regularization on the weights (Lasso Regression). When working with a large number of features, it might improve speed performances. It can be any integer. Default is 0.
#
#     lambda (reg_lambda): L2 regularization on the weights (Ridge Regression). It might help to reduce overfitting. It can be any integer. Default is 1.
#
#     gamma: Gamma is a pseudo-regularisation parameter (Lagrangian multiplier), and depends on the other parameters. The higher Gamma is, the higher the regularization. It can be any integer. Default is 0.
#
# The last three hyperparameters - alpha, lambda, and gamma - are related to the regularization of the model. In machine learning, regularization is a number of techniques to reduce the model complexity and the chances of overfitting.
#
# If you want to know more about these hyperparameters, you can read the XGBoost documentation.
#
# Here, we will focus on the tuning of max_depth and n_estimators.
#
# One note is that this grid search may take several minutes, which is longer than CART or random forest.

# %%
# values of max_depth and min_samples_split
hyperparameters = {'max_depth':[10,20,30,40,50], 'n_estimators':[50,100,150,200,250]}

randomState_xgb = 125
xgb = XGBRegressor(random_state=randomState_xgb)

# cv=5 by default, which means 5-fold cross-validation
gscv_xgb = GridSearchCV(xgb, hyperparameters)

gscv_xgb.fit(train_x, train_y)

# we can query the best parameter value and its accuracy score
print ("The best parameter value is: ")
print (gscv_xgb.best_params_)
print ("The best score is: ")
print (gscv_xgb.score(train_x, train_y))
# Out:
# The best parameter value is:
# {'max_depth': 10, 'n_estimators': 250}
# The best score is:
# 0.999999999999653

# %% [markdown]
# Train the final XGBoost.

# %%
xgb_final = XGBRegressor(max_depth=gscv_xgb.best_params_['max_depth'], n_estimators=gscv_xgb.best_params_['n_estimators'], random_state=randomState_xgb)
xgb_final.fit(train_x, train_y)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=250, n_jobs=None,
#              num_parallel_tree=None, random_state=125, ...)

# %%
print("R2 on the training data:")
print(xgb_final.score(X=train_x, y=train_y))
print("R2 on the testing data:")
print(xgb_final.score(X=test_x, y=test_y))
# Out:
# R2 on the training data:
# 0.999999999999653
# R2 on the testing data:
# 0.8273557242046816

# %% [markdown]
# So - what do you think about the comparison of R2 on the training and testing data?
#
# The R2 on the testing data of XGBoost is much higher than CART and similar to RF, meaning that XGBoost is much better at making prediction for the unseen data and has a better generality.

# %%
print("RMSE on the training data:")
print(mean_squared_error(train_y, xgb_final.predict(train_x), squared=False))
print("RMSE on the testing data:")
print(mean_squared_error(test_y, xgb_final.predict(test_x), squared=False))
# Out:
# RMSE on the training data:
# 0.0011514251431562696
# RMSE on the testing data:
# 779.0513482158586

# %% [markdown]
# As with CART, it is not useful to visualise the trees in a random forest.
#
# Calculate and plot the feature importance of the XGboost model.
#
# Although the feature importance value differs from the CART, the order of the top-ranking variables is the same.
#
# This indicates that these variables are indeed very important for the prediction of bike rental.

# %%
imp = rfpimp.importances(xgb_final,  test_x, test_y) # permutation
print(imp)
viz = rfpimp.plot_importances(imp)
viz.view()
# Out:
#                                                          Importance
# Feature
# days_since_2011                                              0.7760
# temp                                                         0.4832
# hum                                                          0.0536
# windspeed                                                    0.0294
# weathersit_RAIN/SNOW/STORM                                   0.0084
# season_WINTER                                                0.0082
# weathersit_MISTY                                             0.0060
# weekday_TUE                                                  0.0052
# weekday_SAT                                                  0.0037
# weekday_FRI                                                  0.0026
# workingday_NO WORKING DAY                                    0.0024
# weekday_WED                                                  0.0012
# mnth_SEP                                                     0.0001
# season_SUMMER                                                0.0001
# mnth_DEZ                                                     0.0001
# mnth_APR                                                     0.0000
# mnth_AUG                                                    -0.0000
# mnth_MAR                                                    -0.0000
# mnth_FEB                                                    -0.0000
# mnth_NOV                                                    -0.0002
# weekday_THU                                                 -0.0002
# weekday_SUN                                                 -0.0005
# season_FALL                                                 -0.0006
# mnth_JUN                                                    -0.0006
# mnth_JUL                                                    -0.0008
# holiday_HOLIDAY                                             -0.0010
# mnth_MAY                                                    -0.0019
# mnth_OKT                                                    -0.0039

# %% [markdown]
# Comparing three models
#
# we will collate and compare the model performance of the three models.

# %%
# create a list of models
list_name_models = ['CART', 'RF', 'XGBoost']
# use the models from above
list_reg_models = [dt_final, rf_final, xgb_final]

dict_models = dict()

for name, model in zip(list_name_models, list_reg_models):
    dict_models[name] = [model.score(train_x, train_y), model.score(test_x, test_y), model.score(train_x, train_y) - model.score(test_x, test_y)]

# transform dict_models to dataframe
df_models = pd.DataFrame.from_dict(dict_models, orient='index', columns=['R2_train_data', 'R2_test_data', 'R2_diff'])
df_models
# you can then export df_models as a csv file and use it in MS Excel or Word
# df_models.to_csv(...)
# Out:
#                                    R2_train_data  \
# CART                                      0.9727
# RF                                        0.9818
# XGBoost                                   1.0000
#
#                                     R2_test_data  \
# CART                                      0.7577
# RF                                        0.8836
# XGBoost                                   0.8274
#
#                                          R2_diff
# CART                                      0.2150
# RF                                        0.0982
# XGBoost                                   0.1726

# %% [markdown]
# In this workshop, we have used decision trees, random forest, and gradient boosting decision trees to make predictions for the daily bicycle rental.
#
# We compare the model performance and the feature importance. Overall, the RF and GBDT models have better predictive performance and better generalisation than CART.
#
# The trend of relative feature importance is consistent across the three models. The most important features are days since 2011, temperature, and humidity.
#
# In the later weeks, we will demonstrate the use of these models for classification tasks and the scalability of these models for big data.

# %% [markdown]
# Additional Practical:
#
# ## Ensemble!
# ### Basic Mathods in Ensemble Learning
#
# Use these for practical 3:
#
# Bagging(Bootstrap Aggregating)
#
# Boosting
#
# Stacking
#
#
# Bootstrap, bagging, boosting, and stacking are all ensemble techniques used in machine learning, but they differ in their approaches and objectives. Let's break down each one:
# 1. Bootstrap
#
#     Bootstrap is a statistical method used to sample a dataset. It involves randomly selecting a sample of data from a dataset, with replacement. This means the same data point can be picked more than once.
#     In machine learning, bootstrap samples are often used in ensemble methods to create different training datasets. Each model in the ensemble is then trained on a different bootstrap sample.
#
# 2. Bagging (Bootstrap Aggregating)
#
#     Bagging is an ensemble technique that improves the stability and accuracy of machine learning algorithms. It reduces variance and helps to avoid overfitting.
#     In bagging, multiple models (often of the same type) are trained independently on different bootstrap samples of the dataset. The final prediction is made by averaging the predictions of each model (for regression) or by majority voting (for classification).
#     A classic example of bagging is the Random Forest algorithm, where multiple decision trees are trained on different samples of the dataset.
#
# 3. Boosting
#
#     Boosting is another ensemble technique, but unlike bagging, the models are not trained independently of each other. Instead, they are trained sequentially, with each new model focusing on the data points that were incorrectly predicted by the previous ones.
#     The idea is to improve the accuracy by continuously giving more weight to the misclassified observations, so that subsequent models focus more on these difficult cases.
#     Boosting often leads to better predictive accuracy than bagging, but it can also be more prone to overfitting if not managed properly.
#     Examples include AdaBoost, Gradient Boosting, and XGBoost.
#
# 4. Stacking
#
#     Stacking (or stacked generalization) involves training a new model to combine the predictions of several other models.
#     In stacking, different models are trained on the same dataset, and a new model, often called a meta-model, is trained to make a final prediction based on the predictions of the other models.
#     The base models can be of different types (e.g., decision tree, logistic regression, etc.), and the meta-model learns how best to combine their predictions.
#     Stacking is often used when the goal is to push the performance a bit further after exploiting simpler methods like bagging or boosting.
#
# Summary
#
#     Bootstrap is a method for creating multiple versions of a dataset through random sampling with replacement.
#     Bagging reduces variance by training multiple models in parallel on different bootstrap samples and averaging their predictions.
#     Boosting improves accuracy by training multiple models sequentially, each focusing on the errors of the previous ones.
#     Stacking combines the predictions of multiple models using a meta-model, capitalizing on their individual strengths.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
bike_rental = pd.read_csv('https://raw.githubusercontent.com/huanfachen/Spatial_Data_Science/main/Dataset/daily_count_bike_rental.csv')

# %%
# Import the class
from diy_func.diy_ensemble import diy_ensemble

# Create an instance of the class
ensemble = diy_ensemble(3,bike_rental, 100, 100, 100)

ensemble.diy_boostrap(bike_rental, 100, 100, 100)
#diy_boostrap(bike_rental, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100)
# Out:
# [      cnt  season mnth     holiday weekday      workingday       weathersit  \
#  520  6998  SUMMER  JUN  NO HOLIDAY     MON     WORKING DAY             GOOD
#  79   2077  SUMMER  MAR  NO HOLIDAY     MON     WORKING DAY            MISTY
#  350  2739  WINTER  DEZ  NO HOLIDAY     SAT  NO WORKING DAY            MISTY
#  53   1917  SPRING  FEB  NO HOLIDAY     WED     WORKING DAY             GOOD
#  578  7580    FALL  AUG  NO HOLIDAY     WED     WORKING DAY             GOOD
#  526  6598  SUMMER  JUN  NO HOLIDAY     SUN  NO WORKING DAY             GOOD
#  280  5409  WINTER  OKT  NO HOLIDAY     SAT  NO WORKING DAY             GOOD
#  655  7461  WINTER  OKT  NO HOLIDAY     WED     WORKING DAY             GOOD
#  228  4694    FALL  AUG  NO HOLIDAY     WED     WORKING DAY             GOOD
#  316  3717  WINTER  NOV  NO HOLIDAY     SUN  NO WORKING DAY             GOOD
#  570  7592    FALL  JUL  NO HOLIDAY     TUE     WORKING DAY             GOOD
#  507  6073  SUMMER  MAY  NO HOLIDAY     TUE     WORKING DAY            MISTY
#  649  7570  WINTER  OKT  NO HOLIDAY     THU     WORKING DAY             GOOD
#  93   3115  SUMMER  APR  NO HOLIDAY     MON     WORKING DAY             GOOD
#  86   2028  SUMMER  MAR  NO HOLIDAY     MON     WORKING DAY             GOOD
#  386  1977  SPRING  JAN  NO HOLIDAY     SUN  NO WORKING DAY            MISTY
#  667    22  WINTER  OKT  NO HOLIDAY     MON     WORKING DAY  RAIN/SNOW/STORM
#  415  3129  SPRING  FEB     HOLIDAY     MON  NO WORKING DAY             GOOD
#  141  4660  SUMMER  MAY  NO HOLIDAY     SUN  NO WORKING DAY             GOOD
#  723   920  SPRING  DEZ  NO HOLIDAY     MON     WORKING DAY            MISTY
#  612  6864    FALL  SEP  NO HOLIDAY     TUE     WORKING DAY             GOOD
#  4    1600  SPRING  JAN  NO HOLIDAY     WED     WORKING DAY             GOOD
#  603  5255    FALL  AUG  NO HOLIDAY     SUN  NO WORKING DAY            MISTY
#  135  3958  SUMMER  MAY  NO HOLIDAY     MON     WORKING DAY             GOOD
#  49   1635  SPRING  FEB  NO HOLIDAY     SAT  NO WORKING DAY             GOOD
#  431  4916  SPRING  MAR  NO HOLIDAY     WED     WORKING DAY             GOOD
#  705  5375  WINTER  DEZ  NO HOLIDAY     THU     WORKING DAY             GOOD
#  317  4486  WINTER  NOV  NO HOLIDAY     MON     WORKING DAY             GOOD
#  695  5087  WINTER  NOV  NO HOLIDAY     MON     WORKING DAY             GOOD
#  336  3614  WINTER  DEZ  NO HOLIDAY     SAT  NO WORKING DAY             GOOD
#  2    1349  SPRING  JAN  NO HOLIDAY     MON     WORKING DAY             GOOD
#  617  8227    FALL  SEP  NO HOLIDAY     SUN  NO WORKING DAY             GOOD
#  478  3214  SUMMER  APR  NO HOLIDAY     MON     WORKING DAY            MISTY
#  403  2802  SPRING  FEB  NO HOLIDAY     WED     WORKING DAY            MISTY
#  63   2077  SPRING  MAR  NO HOLIDAY     SAT  NO WORKING DAY            MISTY
#  181  5362    FALL  JUL  NO HOLIDAY     FRI     WORKING DAY             GOOD
#  283  4563  WINTER  OKT  NO HOLIDAY     TUE     WORKING DAY            MISTY
#  238  1115    FALL  AUG  NO HOLIDAY     SAT  NO WORKING DAY            MISTY
#  369  3272  SPRING  JAN  NO HOLIDAY     THU     WORKING DAY             GOOD
#  303  3669  WINTER  OKT  NO HOLIDAY     MON     WORKING DAY             GOOD
#  679  6536  WINTER  NOV  NO HOLIDAY     SAT  NO WORKING DAY             GOOD
#  172  4507    FALL  JUN  NO HOLIDAY     WED     WORKING DAY             GOOD
#  274  2918  WINTER  OKT  NO HOLIDAY     SUN  NO WORKING DAY            MISTY
#  192  4258    FALL  JUL  NO HOLIDAY     TUE     WORKING DAY             GOOD
#  437  5847  SPRING  MAR  NO HOLIDAY     TUE     WORKING DAY             GOOD
#  714  5047  WINTER  DEZ  NO HOLIDAY     SAT  NO WORKING DAY             GOOD
#  273  2429  WINTER  OKT  NO HOLIDAY     SAT  NO WORKING DAY            MISTY
#  584  7273    FALL  AUG  NO HOLIDAY     TUE     WORKING DAY            MISTY
#  525  7498  SUMMER  JUN  NO HOLIDAY     SAT  NO WORKING DAY             GOOD
#  618  7525    FALL  SEP  NO HOLIDAY     MON     WORKING DAY             GOOD
#  30   1501  SPRING  JAN  NO HOLIDAY     MON     WORKING DAY            MISTY
#  17    683  SPRING  JAN  NO HOLIDAY     TUE     WORKING DAY            MISTY
#  53   1917  SPRING  FEB  NO HOLIDAY     WED     WORKING DAY             GOOD
#  68    623  SPRING  MAR  NO HOLIDAY     THU     WORKING DAY  RAIN/SNOW/STORM
#  488  6421  SUMMER  MAY  NO HOLIDAY     THU     WORKING DAY            MISTY
#  347  3740  WINTER  DEZ  NO HOLIDAY     WED     WORKING DAY            MISTY
#  475  7290  SUMMER  APR  NO HOLIDAY     FRI     WORKING DAY             GOOD
#  693  2277  WINTER  NOV  NO HOLIDAY     SAT  NO WORKING DAY             GOOD
#  0     985  SPRING  JAN  NO HOLIDAY     SAT  NO WORKING DAY            MISTY
#  13   1421  SPRING  JAN  NO HOLIDAY     FRI     WORKING DAY             GOOD
#  185  4665    FALL  JUL  NO HOLIDAY     TUE     WORKING DAY             GOOD
#  460  6457  SUMMER  APR  NO HOLIDAY     THU     WORKING DAY             GOOD
#  362  2423  SPRING  DEZ  NO HOLIDAY     THU     WORKING DAY             GOOD
#  131  4864  SUMMER  MAY  NO HOLIDAY     THU     WORKING DAY             GOOD
#  582  5464    FALL  AUG  NO HOLIDAY     SUN  NO WORKING DAY             GOOD
#  643  8156  WINTER  OKT  NO HOLIDAY     FRI     WORKING DAY             GOOD
#  212  4266    FALL  AUG  NO HOLIDAY     MON     WORKING DAY             GOOD
#  719  4128  WINTER  DEZ  NO HOLIDAY     THU     WORKING DAY            MISTY
#  394  3624  SPRING  JAN  NO HOLIDAY     MON     WORKING DAY             GOOD
#  215  4576    FALL  AUG  NO HOLIDAY     THU     WORKING DAY            MISTY
#  502  7384  SUMMER  MAY  NO HOLIDAY     THU     WORKING DAY             GOOD
#  495  6572  SUMMER  MAY  NO HOLIDAY     THU     WORKING DAY             GOOD
#  643  8156  WINTER  OKT  NO HOLIDAY     FRI     WORKING DAY             GOOD
#  176  5305    FALL  JUN  NO HOLIDAY     SUN  NO WORKING DAY             GOOD
#  180  5515    FALL  JUN  NO HOLIDAY     THU     WORKING DAY             GOOD
#  36   1623  SPRING  FEB  NO HOLIDAY     SUN  NO WORKING DAY             GOOD
#  38   1530  SPRING  FEB  NO HOLIDAY     TUE     WORKING DAY             GOOD
#  214  3574    FALL  AUG  NO HOLIDAY     WED     WORKING DAY            MISTY
#  94   1795  SUMMER  APR  NO HOLIDAY     TUE     WORKING DAY            MISTY
#  170  4010  SUMMER  JUN  NO HOLIDAY     MON     WORKING DAY            MISTY
#  95   2808  SUMMER  APR  NO HOLIDAY     WED     WORKING DAY             GOOD
#  626  4073    FALL  SEP  NO HOLIDAY     TUE     WORKING DAY            MISTY
#  631  7907  WINTER  SEP  NO HOLIDAY     SUN  NO WORKING DAY             GOOD
#  76   3239  SPRING  MAR  NO HOLIDAY     FRI     WORKING DAY             GOOD
#  314  3368  WINTER  NOV     HOLIDAY     FRI  NO WORKING DAY             GOOD
#  102  2162  SUMMER  APR  NO HOLIDAY     WED     WORKING DAY            MISTY
#  406  2169  SPRING  FEB  NO HOLIDAY     SAT  NO WORKING DAY  RAIN/SNOW/STORM
#  256  4785    FALL  SEP  NO HOLIDAY     WED     WORKING DAY             GOOD
#  695  5087  WINTER  NOV  NO HOLIDAY     MON     WORKING DAY             GOOD
#  226  4338    FALL  AUG  NO HOLIDAY     MON     WORKING DAY             GOOD
#  196  5923    FALL  JUL  NO HOLIDAY     SAT  NO WORKING DAY             GOOD
#  446  6871  SUMMER  MAR  NO HOLIDAY     THU     WORKING DAY             GOOD
#  452  5698  SUMMER  MAR  NO HOLIDAY     WED     WORKING DAY             GOOD
#  419  3487  SPRING  FEB  NO HOLIDAY     FRI     WORKING DAY            MISTY
#  407  1529  SPRING  FEB  NO HOLIDAY     SUN  NO WORKING DAY             GOOD
#  521  7001  SUMMER  JUN  NO HOLIDAY     TUE     WORKING DAY            MISTY
#  496  7030  SUMMER  MAY  NO HOLIDAY     FRI     WORKING DAY             GOOD
#  409  3922  SPRING  FEB  NO HOLIDAY     TUE     WORKING DAY            MISTY
#  438  6312  SPRING  MAR  NO HOLIDAY     WED     WORKING DAY             GOOD
#  262  3641    FALL  SEP  NO HOLIDAY     TUE     WORKING DAY            MISTY
#
#                                          temp  \
#  520                                  20.0825
#  79                                   12.2304
#  350                                   4.1417
#  53                                    2.4217
#  578                                  25.7225
#  526                                  26.1533
#  280                                  16.5183
#  655                                  13.4242
#  228                                  25.9967
#  316                                  12.7192
#  570                                  27.2892
#  507                                  20.9050
#  649                                  12.4450
#  93                                   18.9467
#  86                                    4.4244
#  386                                  -0.3625
#  667                                  12.6800
#  415                                   5.1600
#  141                                  20.3958
#  723                                   2.8713
#  612                                  26.1142
#  4                                     2.6670
#  603                                  22.7067
#  135                                  19.1425
#  49                                   10.7608
#  431                                  10.9958
#  705                                   4.0242
#  317                                  16.9100
#  695                                   6.7267
#  336                                   6.0608
#  2                                     1.2291
#  617                                  20.6700
#  478                                   7.1183
#  403                                   4.0633
#  63                                   10.0558
#  181                                  25.9575
#  283                                  18.6333
#  238                                  23.9600
#  369                                   4.4942
#  303                                   7.9800
#  679                                  10.2908
#  172                                  26.4667
#  274                                   8.7633
#  192                                  29.3258
#  437                                  18.5550
#  714                                   7.2358
#  273                                  11.2700
#  584                                  26.5842
#  525                                  25.4092
#  618                                  19.4167
#  30                                    0.4992
#  17                                    2.1833
#  53                                    2.4217
#  68                                   10.2873
#  488                                  18.3200
#  347                                   6.9225
#  475                                  16.7533
#  693                                   5.0817
#  0                                     8.1758
#  13                                   -0.4391
#  185                                  27.0933
#  460                                  12.4450
#  362                                   3.6717
#  131                                  17.1450
#  582                                  28.1508
#  643                                  20.9050
#  212                                  28.2683
#  719                                   7.5100
#  394                                   4.6508
#  215                                  25.3700
#  502                                  19.8867
#  495                                  15.7742
#  643                                  20.9050
#  176                                  23.9600
#  180                                  24.7433
#  36                                    5.4342
#  38                                    2.3792
#  214                                  26.3883
#  94                                   11.4658
#  170                                  21.8450
#  95                                   10.3692
#  626                                  21.2967
#  631                                  16.8708
#  76                                   17.3800
#  314                                   7.2358
#  102                                  11.3875
#  406                                   2.5358
#  256                                  23.6467
#  695                                   6.7267
#  226                                  23.2942
#  196                                  24.2733
#  446                                  18.0458
#  452                                  14.7558
#  419                                  11.1525
#  407                                  -2.0075
#  521                                  17.4192
#  496                                  17.0667
#  409                                   7.0008
#  438                                  18.9075
#  262                                  18.3983
#
#                                           hum  \
#  520                                  48.7083
#  79                                   73.7391
#  350                                  56.0833
#  53                                   42.3043
#  578                                  67.7500
#  526                                  53.8333
#  280                                  70.1250
#  655                                  69.2917
#  228                                  57.5417
#  316                                  45.8333
#  570                                  65.5000
#  507                                  76.5833
#  649                                  46.3333
#  93                                   42.6250
#  86                                   30.2174
#  386                                  79.6250
#  667                                  88.0000
#  415                                  50.7826
#  141                                  74.9583
#  723                                  79.1304
#  612                                  75.5000
#  4                                    43.6957
#  603                                  84.5833
#  135                                  78.7917
#  49                                   18.7917
#  431                                  51.3333
#  705                                  50.8750
#  317                                  58.7083
#  695                                  53.5417
#  336                                  61.2917
#  2                                    43.7273
#  617                                  54.7500
#  478                                  76.6667
#  403                                  72.2917
#  63                                   78.9167
#  181                                  39.6250
#  283                                  80.8750
#  238                                  85.0000
#  369                                  52.4167
#  303                                  70.3333
#  679                                  64.5417
#  172                                  70.7500
#  274                                  79.1667
#  192                                  55.9167
#  437                                  61.7500
#  714                                  65.0417
#  273                                  75.3750
#  584                                  70.3750
#  525                                  43.7083
#  618                                  50.3750
#  30                                   60.3750
#  17                                   86.1667
#  53                                   42.3043
#  68                                    0.0000
#  488                                  76.8333
#  347                                  66.3750
#  475                                  69.4583
#  693                                  40.4583
#  0                                    80.5833
#  13                                   53.7826
#  185                                  59.0417
#  460                                  37.4167
#  362                                  57.4167
#  131                                  74.7500
#  582                                  65.2500
#  643                                  62.7500
#  212                                  55.0833
#  719                                  66.7917
#  394                                  40.0833
#  215                                  75.7500
#  502                                  52.0000
#  495                                  55.2083
#  643                                  62.7500
#  176                                  51.3333
#  180                                  43.4167
#  36                                   56.8333
#  38                                   53.7917
#  214                                  65.7500
#  94                                   64.2083
#  170                                  74.6250
#  95                                   47.0833
#  626                                  87.2500
#  631                                  46.7083
#  76                                   52.5217
#  314                                  44.6250
#  102                                  81.9167
#  406                                  73.1250
#  256                                  69.7083
#  695                                  53.5417
#  226                                  71.2083
#  196                                  58.5000
#  446                                  83.1250
#  452                                  48.1250
#  419                                  73.7500
#  407                                  46.4583
#  521                                  61.3333
#  496                                  36.0417
#  409                                  50.8750
#  438                                  50.7083
#  262                                  88.1250
#
#                                     windspeed  days_since_2011
#  520                                  19.0838              520
#  79                                   19.3485               79
#  350                                  16.2922              350
#  53                                    6.3056               53
#  578                                   9.4590              578
#  526                                   8.9593              526
#  280                                   3.0421              280
#  655                                   6.7919              655
#  228                                   9.6257              228
#  316                                  18.8753              316
#  570                                  14.1674              570
#  507                                   7.9172              507
#  649                                  12.1669              649
#  93                                   25.8333               93
#  86                                   14.2177               86
#  386                                  13.3757              386
#  667                                  23.9994              667
#  415                                  15.3486              415
#  141                                   9.9165              141
#  723                                   5.1744              723
#  612                                  15.8335              612
#  4                                    12.5223                4
#  603                                  15.3335              603
#  135                                   8.5004              135
#  49                                   34.0000               49
#  431                                  23.1672              431
#  705                                  11.7085              705
#  317                                  20.5419              317
#  695                                   3.1256              695
#  336                                   6.4175              336
#  2                                    16.6367                2
#  617                                  15.0412              617
#  478                                  20.3342              478
#  403                                   8.9593              403
#  63                                   16.8754               63
#  181                                   6.8747              181
#  283                                   9.5838              283
#  238                                  25.1663              238
#  369                                   8.7091              369
#  303                                   7.1254              303
#  679                                   3.8757              679
#  172                                  11.5416              172
#  274                                  14.8749              274
#  192                                  13.4170              192
#  437                                  15.8757              437
#  714                                   7.1254              714
#  273                                  19.5838              273
#  584                                   7.8328              584
#  525                                   9.6672              525
#  618                                  17.3338              618
#  30                                   12.5419               30
#  17                                    9.8339               17
#  53                                    6.3056               53
#  68                                   17.5458               68
#  488                                   8.9576              488
#  347                                   4.0842              347
#  475                                  10.0414              475
#  693                                  25.2504              693
#  0                                    10.7499                0
#  13                                    8.4787               13
#  185                                   8.4593              185
#  460                                  14.7084              460
#  362                                   8.0006              362
#  131                                  12.7077              131
#  582                                  19.4582              582
#  643                                   7.1254              643
#  212                                  10.5000              212
#  719                                   8.8750              719
#  394                                  14.4581              394
#  215                                  13.2090              215
#  502                                  15.3748              502
#  495                                  21.0422              495
#  643                                   7.1254              643
#  176                                   6.3337              176
#  180                                  12.4159              180
#  36                                    9.5006               36
#  38                                   24.2507               38
#  214                                   9.0841              214
#  94                                   26.0005               94
#  170                                  10.4168              170
#  95                                   17.6252               95
#  626                                  23.9583              626
#  631                                  14.9583              631
#  76                                   15.4781               76
#  314                                  21.0832              314
#  102                                  16.7913              102
#  406                                  19.4163              406
#  256                                  11.2091              256
#  695                                   3.1256              695
#  226                                  13.9999              226
#  196                                  13.9589              196
#  446                                   7.8767              446
#  452                                  19.5420              452
#  419                                  15.9170              419
#  407                                  27.4172              407
#  521                                  14.0415              521
#  496                                  15.8748              496
#  409                                   9.4590              409
#  438                                   7.7092              438
#  262                                   9.0419              262  ,
#        cnt  season mnth     holiday weekday      workingday       weathersit  \
#  677  5315  WINTER  NOV  NO HOLIDAY     THU     WORKING DAY             GOOD
#  122  4451  SUMMER  MAY  NO HOLIDAY     TUE     WORKING DAY            MISTY
#  628  7720    FALL  SEP  NO HOLIDAY     THU     WORKING DAY             GOOD
#  186  4629    FALL  JUL  NO HOLIDAY     WED     WORKING DAY             GOOD
#  295  4381  WINTER  OKT  NO HOLIDAY     SUN  NO WORKING DAY             GOOD
#  619  7767    FALL  SEP  NO HOLIDAY     TUE     WORKING DAY             GOOD
#  286  3644  WINTER  OKT  NO HOLIDAY     FRI     WORKING DAY            MISTY
#  578  7580    FALL  AUG  NO HOLIDAY     WED     WORKING DAY             GOOD
#  243  5115    FALL  SEP  NO HOLIDAY     THU     WORKING DAY             GOOD
#  439  6192  SPRING  MAR  NO HOLIDAY     THU     WORKING DAY             GOOD
#  273  2429  WINTER  OKT  NO HOLIDAY     SAT  NO WORKING DAY            MISTY
#  485  5572  SUMMER  APR  NO HOLIDAY     MON     WORKING DAY            MISTY
#  89   1685  SUMMER  MAR  NO HOLIDAY     THU     WORKING DAY  RAIN/SNOW/STORM
#  429  3333  SPRING  MAR  NO HOLIDAY     MON     WORKING DAY             GOOD
#  16   1000  SPRING  JAN     HOLIDAY     MON  NO WORKING DAY            MISTY
#  524  7736  SUMMER  JUN  NO HOLIDAY     FRI     WORKING DAY             GOOD
#  466  4862  SUMMER  APR  NO HOLIDAY     WED     WORKING DAY             GOOD
#  621  7804    FALL  SEP  NO HOLIDAY     THU     WORKING DAY             GOOD
#  67   1891  SPRING  MAR  NO HOLIDAY     WED     WORKING DAY            MISTY
#  220  4602    FALL  AUG  NO HOLIDAY     TUE     WORKING DAY             GOOD
#  223  4905    FALL  AUG  NO HOLIDAY     FRI     WORKING DAY             GOOD
#  138  4575  SUMMER  MAY  NO HOLIDAY     THU     WORKING DAY            MISTY
#  473  4367  SUMMER  APR  NO HOLIDAY     WED     WORKING DAY            MISTY
#  712  5532  WINTER  DEZ  NO HOLIDAY     THU     WORKING DAY             GOOD
#  414  2689  SPRING  FEB  NO HOLIDAY     SUN  NO WORKING DAY            MISTY
#  658  8090  WINTER  OKT  NO HOLIDAY     SAT  NO WORKING DAY             GOOD
#  349  3577  WINTER  DEZ  NO HOLIDAY     FRI     WORKING DAY            MISTY
#  604  6917    FALL  AUG  NO HOLIDAY     MON     WORKING DAY             GOOD
#  556  6290    FALL  JUL  NO HOLIDAY     TUE     WORKING DAY            MISTY
#  245  4484    FALL  SEP  NO HOLIDAY     SAT  NO WORKING DAY             GOOD
#  57   2402  SPRING  FEB  NO HOLIDAY     SUN  NO WORKING DAY             GOOD
#  383  3292  SPRING  JAN  NO HOLIDAY     THU     WORKING DAY             GOOD
#  585  7534    FALL  AUG  NO HOLIDAY     WED     WORKING DAY            MISTY
#  694  2424  WINTER  NOV  NO HOLIDAY     SUN  NO WORKING DAY             GOOD
#  656  7509  WINTER  OKT  NO HOLIDAY     THU     WORKING DAY            MISTY
#  389  4270  SPRING  JAN  NO HOLIDAY     WED     WORKING DAY             GOOD
#  435  4911  SPRING  MAR  NO HOLIDAY     SUN  NO WORKING DAY             GOOD
#  346  3523  WINTER  DEZ  NO HOLIDAY     TUE     WORKING DAY             GOOD
#  34   1708  SPRING  FEB  NO HOLIDAY     FRI     WORKING DAY            MISTY
#  451  5102  SUMMER  MAR  NO HOLIDAY     TUE     WORKING DAY             GOOD
#  694  2424  WINTER  NOV  NO HOLIDAY     SUN  NO WORKING DAY             GOOD
#  77   3117  SPRING  MAR  NO HOLIDAY     SAT  NO WORKING DAY             GOOD
#  212  4266    FALL  AUG  NO HOLIDAY     MON     WORKING DAY             GOOD
#  385  1301  SPRING  JAN  NO HOLIDAY     SAT  NO WORKING DAY            MISTY
#  14   1248  SPRING  JAN  NO HOLIDAY     SAT  NO WORKING DAY            MISTY
#  289  4570  WINTER  OKT  NO HOLIDAY     MON     WORKING DAY             GOOD
#  148  4788  SUMMER  MAY  NO HOLIDAY     SUN  NO WORKING DAY             GOOD
#  168  5119  SUMMER  JUN  NO HOLIDAY     SAT  NO WORKING DAY             GOOD
#  536  6211  SUMMER  JUN  NO HOLIDAY     WED     WORKING DAY             GOOD
#  477  1027  SUMMER  APR  NO HOLIDAY     SUN  NO WORKING DAY  RAIN/SNOW/STORM
#  442  5892  SPRING  MAR  NO HOLIDAY     SUN  NO WORKING DAY            MISTY
#  722  1787  SPRING  DEZ  NO HOLIDAY     SUN  NO WORKING DAY             GOOD
#  647  6392  WINTER  OKT  NO HOLIDAY     TUE     WORKING DAY            MISTY
#  478  3214  SUMMER  APR  NO HOLIDAY     MON     WORKING DAY            MISTY
#  514  5743  SUMMER  MAY  NO HOLIDAY     TUE     WORKING DAY             GOOD
#  575  6597    FALL  JUL  NO HOLIDAY     SUN  NO WORKING DAY             GOOD
#  130  4182  SUMMER  MAY  NO HOLIDAY     WED     WORKING DAY             GOOD
#  215  4576    FALL  AUG  NO HOLIDAY     THU     WORKING DAY            MISTY
#  145  4677  SUMMER  MAY  NO HOLIDAY     THU     WORKING DAY             GOOD
#  237  4661    FALL  AUG  NO HOLIDAY     FRI     WORKING DAY             GOOD
#  730  2729  SPRING  DEZ  NO HOLIDAY     MON     WORKING DAY            MISTY
#  250  1842    FALL  SEP  NO HOLIDAY     THU     WORKING DAY  RAIN/SNOW/STORM
#  477  1027  SUMMER  APR  NO HOLIDAY     SUN  NO WORKING DAY  RAIN/SNOW/STORM
#  74   2192  SPRING  MAR  NO HOLIDAY     WED     WORKING DAY            MISTY
#  437  5847  SPRING  MAR  NO HOLIDAY     TUE     WORKING DAY             GOOD
#  67   1891  SPRING  MAR  NO HOLIDAY     WED     WORKING DAY            MISTY
#  668  1096  WINTER  OKT  NO HOLIDAY     TUE     WORKING DAY            MISTY
#  82   1865  SUMMER  MAR  NO HOLIDAY     THU     WORKING DAY            MISTY
#  401  3784  SPRING  FEB  NO HOLIDAY     MON     WORKING DAY             GOOD
#  653  5875  WINTER  OKT  NO HOLIDAY     MON     WORKING DAY            MISTY
#  593  7605    FALL  AUG  NO HOLIDAY     THU     WORKING DAY             GOOD
#  194  5084    FALL  JUL  NO HOLIDAY     THU     WORKING DAY             GOOD
#  655  7461  WINTER  OKT  NO HOLIDAY     WED     WORKING DAY             GOOD
#  364  2485  SPRING  DEZ  NO HOLIDAY     SAT  NO WORKING DAY             GOOD
#  122  4451  SUMMER  MAY  NO HOLIDAY     TUE     WORKING DAY            MISTY
#  11   1162  SPRING  JAN  NO HOLIDAY     WED     WORKING DAY             GOOD
#  613  7112    FALL  SEP  NO HOLIDAY     WED     WORKING DAY             GOOD
#  38   1530  SPRING  FEB  NO HOLIDAY     TUE     WORKING DAY             GOOD
#  313  2933  WINTER  NOV  NO HOLIDAY     THU     WORKING DAY            MISTY
#  87   2425  SUMMER  MAR  NO HOLIDAY     TUE     WORKING DAY             GOOD
#  691  2425  WINTER  NOV     HOLIDAY     THU  NO WORKING DAY             GOOD
#  506  4359  SUMMER  MAY  NO HOLIDAY     MON     WORKING DAY            MISTY
#  693  2277  WINTER  NOV  NO HOLIDAY     SAT  NO WORKING DAY             GOOD
#  657  5424  WINTER  OKT  NO HOLIDAY     FRI     WORKING DAY            MISTY
#  705  5375  WINTER  DEZ  NO HOLIDAY     THU     WORKING DAY             GOOD
#  298  3894  WINTER  OKT  NO HOLIDAY     WED     WORKING DAY            MISTY
#  172  4507    FALL  JUN  NO HOLIDAY     WED     WORKING DAY             GOOD
#  144  4978  SUMMER  MAY  NO HOLIDAY     WED     WORKING DAY             GOOD
#  182  5119    FALL  JUL  NO HOLIDAY     SAT  NO WORKING DAY             GOOD
#  183  4649    FALL  JUL  NO HOLIDAY     SUN  NO WORKING DAY            MISTY
#  83   2210  SUMMER  MAR  NO HOLIDAY     FRI     WORKING DAY             GOOD
#  502  7384  SUMMER  MAY  NO HOLIDAY     THU     WORKING DAY             GOOD
#  356  2209  SPRING  DEZ  NO HOLIDAY     FRI     WORKING DAY             GOOD
#  554  4672    FALL  JUL  NO HOLIDAY     SUN  NO WORKING DAY             GOOD
#  624  7333    FALL  SEP  NO HOLIDAY     SUN  NO WORKING DAY             GOOD
#  720  3623  SPRING  DEZ  NO HOLIDAY     FRI     WORKING DAY            MISTY
#  113  4191  SUMMER  APR  NO HOLIDAY     SUN  NO WORKING DAY            MISTY
#  258  4760    FALL  SEP  NO HOLIDAY     FRI     WORKING DAY            MISTY
#  318  4195  WINTER  NOV  NO HOLIDAY     TUE     WORKING DAY            MISTY
#  465  5918  SUMMER  APR  NO HOLIDAY     TUE     WORKING DAY             GOOD
#
#                                          temp  \
#  677                                   8.5522
#  122                                  20.9833
#  628                                  17.6933
#  186                                  25.8400
#  295                                  11.8183
#  619                                  19.1425
#  286                                  17.8892
#  578                                  25.7225
#  243                                  22.7850
#  439                                  18.2025
#  273                                  11.2700
#  485                                  13.8158
#  89                                    4.6117
#  429                                   3.4367
#  16                                    0.2642
#  524                                  22.5108
#  466                                   8.3887
#  621                                  20.7875
#  67                                    5.9042
#  220                                  28.4250
#  223                                  25.2917
#  138                                  16.9492
#  473                                  13.7767
#  712                                   5.9042
#  414                                   5.1600
#  658                                  14.7558
#  349                                   9.6250
#  604                                  25.0567
#  556                                  25.8792
#  245                                  23.4508
#  57                                    8.1435
#  383                                   0.9300
#  585                                  27.2500
#  694                                   3.5542
#  656                                  16.5575
#  389                                   5.8258
#  435                                   9.0017
#  346                                   5.2775
#  34                                    1.9313
#  451                                   7.1967
#  694                                   3.5542
#  77                                   14.2075
#  212                                  28.2683
#  385                                   0.1467
#  14                                    2.9667
#  289                                  17.1058
#  148                                  23.3725
#  168                                  24.7433
#  536                                  28.7775
#  477                                  10.6433
#  442                                  14.2075
#  722                                   3.5542
#  647                                  12.9933
#  478                                   7.1183
#  514                                  25.9575
#  575                                  25.9183
#  130                                  17.4975
#  215                                  25.3700
#  145                                  25.2917
#  237                                  24.9000
#  730                                   2.1442
#  250                                  21.7939
#  477                                  10.6433
#  74                                    9.1652
#  437                                  18.5550
#  67                                    5.9042
#  668                                   6.9546
#  82                                    5.3950
#  401                                   5.2826
#  653                                  18.3983
#  593                                  25.8008
#  194                                  23.9992
#  655                                  13.4242
#  364                                  11.2700
#  122                                  20.9833
#  11                                    0.1182
#  613                                  26.6233
#  38                                    2.3792
#  313                                   9.8600
#  87                                    6.2175
#  691                                   7.9800
#  506                                  20.1217
#  693                                   5.0817
#  657                                  18.4767
#  705                                   4.0242
#  298                                  14.7558
#  172                                  26.4667
#  144                                  23.0592
#  182                                  26.7017
#  183                                  25.6833
#  83                                    4.4158
#  502                                  19.8867
#  356                                   9.5467
#  554                                  30.6575
#  624                                  19.2600
#  720                                   7.3533
#  113                                  19.3383
#  258                                  14.0508
#  318                                  16.9100
#  465                                  12.9933
#
#                                           hum  \
#  677                                  33.3478
#  122                                  69.7083
#  628                                  61.8333
#  186                                  74.3333
#  295                                  74.1250
#  619                                  52.0000
#  286                                  71.6250
#  578                                  67.7500
#  243                                  63.9167
#  439                                  57.9583
#  273                                  75.3750
#  485                                  57.0000
#  89                                   91.8333
#  429                                  50.6250
#  16                                   53.7500
#  524                                  46.7917
#  466                                  46.9565
#  621                                  63.7083
#  67                                   77.5417
#  220                                  57.0417
#  223                                  41.5000
#  138                                  82.9583
#  473                                  56.9167
#  712                                  48.5833
#  414                                  51.5833
#  658                                  57.2917
#  349                                  50.0417
#  604                                  73.0417
#  556                                  66.7500
#  245                                  71.6667
#  57                                   68.0000
#  383                                  49.7500
#  585                                  67.2917
#  694                                  46.8333
#  656                                  72.8333
#  389                                  64.3750
#  435                                  47.6957
#  346                                  59.0000
#  34                                   58.5217
#  451                                  29.0000
#  694                                  46.8333
#  77                                   37.9167
#  212                                  55.0833
#  385                                  83.1250
#  14                                   49.8750
#  289                                  57.9583
#  148                                  81.8750
#  168                                  67.0417
#  536                                  59.2083
#  477                                  83.5417
#  442                                  81.0000
#  722                                  51.5417
#  647                                  76.1667
#  478                                  76.6667
#  514                                  68.4583
#  575                                  62.3750
#  130                                  63.2917
#  215                                  75.7500
#  145                                  67.7500
#  237                                  76.1250
#  730                                  57.7500
#  250                                  93.9565
#  477                                  83.5417
#  74                                   77.6522
#  437                                  61.7500
#  67                                   77.5417
#  668                                  82.5455
#  82                                   80.5833
#  401                                  62.2174
#  653                                  70.7500
#  593                                  51.9167
#  194                                  47.6250
#  655                                  69.2917
#  364                                  61.5833
#  122                                  69.7083
#  11                                   59.9545
#  613                                  74.1250
#  38                                   53.7917
#  313                                  81.3333
#  87                                   31.4167
#  691                                  58.0417
#  506                                  81.1250
#  693                                  40.4583
#  657                                  81.5000
#  705                                  50.8750
#  298                                  72.0417
#  172                                  70.7500
#  144                                  69.6250
#  182                                  44.4583
#  183                                  68.2500
#  83                                   49.5000
#  502                                  52.0000
#  356                                  68.6250
#  554                                  57.3750
#  624                                  57.0000
#  720                                  55.6667
#  113                                  81.0833
#  258                                  59.0417
#  318                                  68.8750
#  465                                  43.5000
#
#                                     windspeed  days_since_2011
#  677                                  23.3049              677
#  122                                  22.9587              122
#  628                                   7.9172              628
#  186                                  10.0422              186
#  295                                   6.6673              295
#  619                                   6.1676              619
#  286                                  15.0002              286
#  578                                   9.4590              578
#  243                                   9.5003              243
#  439                                  10.0422              439
#  273                                  19.5838              273
#  485                                  11.4997              485
#  89                                   14.5823               89
#  429                                  15.3335              429
#  16                                   12.9991               16
#  524                                  11.7507              524
#  466                                  19.7834              466
#  621                                   5.5423              621
#  67                                   14.7500               67
#  220                                  10.1251              220
#  223                                   8.4166              223
#  138                                   7.2503              138
#  473                                  11.2501              473
#  712                                  11.6666              712
#  414                                  16.9585              414
#  658                                   7.8750              658
#  349                                  17.4585              349
#  604                                   8.6251              604
#  556                                  10.1664              556
#  245                                  12.4168              245
#  57                                    8.3916               57
#  383                                  14.7506              383
#  585                                   7.4169              585
#  694                                  10.0835              694
#  656                                  15.8748              656
#  389                                  10.7918              389
#  435                                  14.9133              435
#  346                                   9.4169              346
#  34                                    8.5652               34
#  451                                  12.5419              451
#  694                                  10.0835              694
#  77                                   24.6672               77
#  212                                  10.5000              212
#  385                                  14.9170              385
#  14                                   10.5835               14
#  289                                  11.7504              289
#  148                                  14.3338              148
#  168                                   8.0003              168
#  536                                   7.6254              536
#  477                                  23.0846              477
#  442                                   8.5012              442
#  722                                   8.9166              722
#  647                                  12.7501              647
#  478                                  20.3342              478
#  514                                  19.7918              514
#  575                                  11.4165              575
#  130                                   8.0830              130
#  215                                  13.2090              215
#  145                                  13.3760              145
#  237                                   5.6255              237
#  730                                  10.3747              730
#  250                                  12.9141              250
#  477                                  23.0846              477
#  74                                   13.6088               74
#  437                                  15.8757              437
#  67                                   14.7500               67
#  668                                  14.2716              668
#  82                                   16.3337               82
#  401                                  10.3046              401
#  653                                  19.8345              653
#  593                                   9.5003              593
#  194                                  16.1247              194
#  655                                   6.7919              655
#  364                                  14.7503              364
#  122                                  22.9587              122
#  11                                   20.4100               11
#  613                                  12.5831              613
#  38                                   24.2507               38
#  313                                  12.6675              313
#  87                                   15.2087               87
#  691                                   3.5423              691
#  506                                  15.6247              506
#  693                                  25.2504              693
# ...
#  663                                  17.8500
#  191                                  27.8375
#  234                                  22.1192
#  379                                  -0.1667
#  463                                  15.5000
#  688                                   9.8992
#  28                                    1.2365
#  77                                   14.2075
#  219                                  27.9550
#  232                                  25.4092
#  533                                  19.8475
#  409                                   7.0008
#  330                                  13.5808
#  617                                  20.6700
#  692                                   9.3117
#  127                                  16.8317
#  249                                  20.1608
#  42                                    2.4575
#  522                                  18.0458
#  550                                  29.0908
#  692                                   9.3117
#  215                                  25.3700
#  424                                   8.1844
#  335                                   6.7658
#  526                                  26.1533
#  364                                  11.2700
#  35                                    2.9667
#  120                                  13.2283
#  14                                    2.9667
#  96                                   12.5625
#  589                                  24.9392
#  535                                  24.3517
#  274                                   8.7633
#  293                                  12.0925
#  181                                  25.9575
#  22                                   -3.4635
#  204                                  31.0100
#  448                                  15.6175
#  642                                  22.9025
#  472                                  20.5917
#  199                                  28.5033
#  425                                  14.8342
#  697                                   5.9433
#  315                                   8.7633
#  669                                   8.8025
#  545                                  31.2058
#  670                                   9.1942
#  669                                   8.8025
#  544                                  27.2108
#  320                                   8.0583
#  725                                   3.4367
#  727                                   3.9067
#  197                                  25.8008
#  289                                  17.1058
#  444                                  18.3592
#  276                                  14.7558
#  678                                   8.9983
#  612                                  26.1142
#  69                                    6.8765
#  40                                   -1.2156
#  151                                  27.9158
#  376                                   9.9775
#  301                                   3.9458
#  21                                   -5.2209
#  664                                  17.6542
#  169                                  24.8608
#  55                                    9.1244
#  357                                   6.2175
#  306                                  11.1917
#  308                                   7.3533
#  598                                  22.5108
#  518                                  19.4167
#  136                                  18.3983
#  171                                  23.9992
#  77                                   14.2075
#  396                                  14.0508
#  368                                  -2.9475
#  452                                  14.7558
#  293                                  12.0925
#  671                                   8.6850
#  177                                  24.0775
#  274                                   8.7633
#  354                                  12.1317
#  469                                  15.2650
#  660                                  14.9125
#  647                                  12.9933
#  618                                  19.4167
#  539                                  26.3883
#  239                                  25.2318
#  145                                  25.2917
#  728                                   3.9067
#
#                                           hum  \
#  100                                  71.6956
#  452                                  48.1250
#  173                                  70.3333
#  564                                  57.7083
#  185                                  59.0417
#  313                                  81.3333
#  693                                  40.4583
#  208                                  58.3333
#  632                                  49.2917
#  663                                  80.0417
#  191                                  63.5833
#  234                                  45.5417
#  379                                  41.9167
#  463                                  27.5833
#  688                                  62.3333
#  28                                   65.1739
#  77                                   37.9167
#  219                                  59.2083
#  232                                  77.0000
#  533                                  59.8750
#  409                                  50.8750
#  330                                  69.8333
#  617                                  54.7500
#  692                                  56.8750
#  127                                  63.1667
#  249                                  91.7083
#  42                                   54.4167
#  522                                  61.1250
#  550                                  53.8750
#  692                                  56.8750
#  215                                  75.7500
#  424                                  80.4783
#  335                                  62.5833
#  526                                  53.8333
#  364                                  61.5833
#  35                                   92.9167
#  120                                  76.2083
#  14                                   49.8750
#  96                                   60.2917
#  589                                  53.0417
#  535                                  69.0000
#  274                                  79.1667
#  293                                  57.4167
#  181                                  39.6250
#  22                                   43.6522
#  204                                  55.0833
#  448                                  88.5417
#  642                                  72.2917
#  472                                  39.0417
#  199                                  65.0417
#  425                                  61.5417
#  697                                  50.6250
#  315                                  55.2917
#  669                                  66.6667
#  545                                  48.8750
#  670                                  58.1667
#  669                                  66.6667
#  544                                  42.2500
#  320                                  57.5833
#  725                                  82.3333
#  727                                  59.0000
#  197                                  60.4167
#  289                                  57.9583
#  444                                  80.7917
#  276                                  71.0000
#  678                                  54.0833
#  612                                  75.5000
#  69                                   64.9565
#  40                                   43.7391
#  151                                  67.7083
#  376                                  80.2917
#  301                                  88.2500
#  21                                   40.0000
#  664                                  80.7083
#  169                                  66.6667
#  55                                   71.2174
#  357                                  54.2500
#  306                                  70.2083
#  308                                  51.9167
#  598                                  67.3750
#  518                                  54.9167
#  136                                  83.7917
#  171                                  77.0417
#  77                                   37.9167
#  396                                  50.7917
#  368                                  41.4583
#  452                                  48.1250
#  293                                  57.4167
#  671                                  52.2083
#  177                                  65.8333
#  274                                  79.1667
#  354                                  85.8333
#  469                                  50.2917
#  660                                  56.8333
#  647                                  76.1667
#  618                                  50.3750
#  539                                  53.4583
#  239                                  56.1765
#  145                                  67.7500
#  728                                  75.2917
#
#                                     windspeed  days_since_2011
#  100                                  21.7398              100
#  452                                  19.5420              452
#  173                                  15.9999              173
#  564                                   9.2086              564
#  185                                   8.4593              185
#  313                                  12.6675              313
#  693                                  25.2504              693
#  208                                  11.9581              208
#  632                                   9.5411              632
#  663                                   8.3331              663
#  191                                  18.9166              191
#  234                                   9.8331              234
#  379                                  16.8343              379
#  463                                  15.5839              463
#  688                                  15.7495              688
#  28                                    9.7395               28
#  77                                   24.6672               77
#  219                                  12.8757              219
#  232                                  16.6665              232
#  533                                   9.7086              533
#  409                                   9.4590              409
#  330                                  13.9999              330
#  617                                  15.0412              617
#  692                                   9.9174              692
#  127                                   5.0007              127
#  249                                   6.5004              249
#  42                                   13.6256               42
#  522                                   5.1674              522
#  550                                   9.0417              550
#  692                                   9.9174              692
#  215                                  13.2090              215
#  424                                  12.0008              424
#  335                                   6.7505              335
#  526                                   8.9593              526
#  364                                  14.7503              364
#  35                                   10.7923               35
#  120                                   7.1257              120
#  14                                   10.5835               14
#  96                                   10.8749               96
#  589                                   8.2083              589
#  535                                   9.9171              535
#  274                                  14.8749              274
#  293                                  14.8335              293
#  181                                   6.8747              181
#  22                                   16.5222               22
#  204                                  11.3345              204
#  448                                  12.9165              448
#  642                                   7.8756              642
#  472                                  18.3331              472
#  199                                   8.7502              199
#  425                                  15.2081              425
#  697                                  14.1250              697
#  315                                  14.2082              315
#  669                                  11.1667              669
#  545                                  11.0829              545
#  670                                  10.5422              670
#  669                                  11.1667              669
#  544                                  11.5006              544
#  320                                  20.4593              320
#  725                                  21.2086              725
#  727                                  10.4166              727
#  197                                  16.4172              197
#  289                                  11.7504              289
#  444                                   8.1252              444
#  276                                  13.7922              276
#  678                                  14.3754              678
#  612                                  15.8335              612
#  69                                   15.6090               69
#  40                                   14.8696               40
#  151                                  13.8752              151
#  376                                  12.1248              376
#  301                                  23.5419              301
#  21                                   11.5220               21
#  664                                   8.8753              664
#  169                                   6.8340              169
#  55                                   23.2181               55
#  357                                  12.7504              357
#  306                                   9.1667              306
#  308                                  12.6672              308
#  598                                   4.8756              598
#  518                                  12.4997              518
#  136                                  18.5827              136
#  171                                  11.4587              171
#  77                                   24.6672               77
#  396                                  12.6675              396
#  368                                  12.3749              368
#  452                                  19.5420              452
#  293                                  14.8335              293
#  671                                  17.8337              671
#  177                                   7.2084              177
#  274                                  14.8749              274
#  354                                  14.8338              354
#  469                                  12.7914              469
#  660                                   5.4594              660
#  647                                  12.7501              647
#  618                                  17.3338              618
#  539                                  12.0413              539
#  239                                  20.4122              239
#  145                                  13.3760              145
#  728                                   8.3337              728  ]

# %%
ensemble.diy_boostrap(bike_rental, 5, 2, 100)
# Out:
# [      cnt  season mnth     holiday weekday   workingday weathersit  \
#  520  6998  SUMMER  JUN  NO HOLIDAY     MON  WORKING DAY       GOOD
#  79   2077  SUMMER  MAR  NO HOLIDAY     MON  WORKING DAY      MISTY
#
#                                          temp  \
#  520                                  20.0825
#  79                                   12.2304
#
#                                           hum  \
#  520                                  48.7083
#  79                                   73.7391
#
#                                     windspeed  days_since_2011
#  520                                  19.0838              520
#  79                                   19.3485               79  ,
#        cnt  season mnth     holiday weekday      workingday weathersit  \
#  350  2739  WINTER  DEZ  NO HOLIDAY     SAT  NO WORKING DAY      MISTY
#  53   1917  SPRING  FEB  NO HOLIDAY     WED     WORKING DAY       GOOD
#
#                                          temp  \
#  350                                   4.1417
#  53                                    2.4217
#
#                                           hum  \
#  350                                  56.0833
#  53                                   42.3043
#
#                                     windspeed  days_since_2011
#  350                                  16.2922              350
#  53                                    6.3056               53  ,
#        cnt  season mnth     holiday weekday      workingday weathersit  \
#  578  7580    FALL  AUG  NO HOLIDAY     WED     WORKING DAY       GOOD
#  526  6598  SUMMER  JUN  NO HOLIDAY     SUN  NO WORKING DAY       GOOD
#
#                                          temp  \
#  578                                  25.7225
#  526                                  26.1533
#
#                                           hum  \
#  578                                  67.7500
#  526                                  53.8333
#
#                                     windspeed  days_since_2011
#  578                                   9.4590              578
#  526                                   8.9593              526  ,
#        cnt  season mnth     holiday weekday      workingday weathersit  \
#  280  5409  WINTER  OKT  NO HOLIDAY     SAT  NO WORKING DAY       GOOD
#  655  7461  WINTER  OKT  NO HOLIDAY     WED     WORKING DAY       GOOD
#
#                                          temp  \
#  280                                  16.5183
#  655                                  13.4242
#
#                                           hum  \
#  280                                  70.1250
#  655                                  69.2917
#
#                                     windspeed  days_since_2011
#  280                                   3.0421              280
#  655                                   6.7919              655  ,
#        cnt  season mnth     holiday weekday      workingday weathersit  \
#  228  4694    FALL  AUG  NO HOLIDAY     WED     WORKING DAY       GOOD
#  316  3717  WINTER  NOV  NO HOLIDAY     SUN  NO WORKING DAY       GOOD
#
#                                          temp  \
#  228                                  25.9967
#  316                                  12.7192
#
#                                           hum  \
#  228                                  57.5417
#  316                                  45.8333
#
#                                     windspeed  days_since_2011
#  228                                   9.6257              228
#  316                                  18.8753              316  ]

# %%
bootstrapped_bike_rental = ensemble.diy_boostrap(bike_rental, 5,2,100)

# %%
bootstrapped_bike_rental
# Out:
# [      cnt  season mnth     holiday weekday   workingday weathersit  \
#  520  6998  SUMMER  JUN  NO HOLIDAY     MON  WORKING DAY       GOOD
#  79   2077  SUMMER  MAR  NO HOLIDAY     MON  WORKING DAY      MISTY
#
#                                          temp  \
#  520                                  20.0825
#  79                                   12.2304
#
#                                           hum  \
#  520                                  48.7083
#  79                                   73.7391
#
#                                     windspeed  days_since_2011
#  520                                  19.0838              520
#  79                                   19.3485               79  ,
#        cnt  season mnth     holiday weekday      workingday weathersit  \
#  350  2739  WINTER  DEZ  NO HOLIDAY     SAT  NO WORKING DAY      MISTY
#  53   1917  SPRING  FEB  NO HOLIDAY     WED     WORKING DAY       GOOD
#
#                                          temp  \
#  350                                   4.1417
#  53                                    2.4217
#
#                                           hum  \
#  350                                  56.0833
#  53                                   42.3043
#
#                                     windspeed  days_since_2011
#  350                                  16.2922              350
#  53                                    6.3056               53  ,
#        cnt  season mnth     holiday weekday      workingday weathersit  \
#  578  7580    FALL  AUG  NO HOLIDAY     WED     WORKING DAY       GOOD
#  526  6598  SUMMER  JUN  NO HOLIDAY     SUN  NO WORKING DAY       GOOD
#
#                                          temp  \
#  578                                  25.7225
#  526                                  26.1533
#
#                                           hum  \
#  578                                  67.7500
#  526                                  53.8333
#
#                                     windspeed  days_since_2011
#  578                                   9.4590              578
#  526                                   8.9593              526  ,
#        cnt  season mnth     holiday weekday      workingday weathersit  \
#  280  5409  WINTER  OKT  NO HOLIDAY     SAT  NO WORKING DAY       GOOD
#  655  7461  WINTER  OKT  NO HOLIDAY     WED     WORKING DAY       GOOD
#
#                                          temp  \
#  280                                  16.5183
#  655                                  13.4242
#
#                                           hum  \
#  280                                  70.1250
#  655                                  69.2917
#
#                                     windspeed  days_since_2011
#  280                                   3.0421              280
#  655                                   6.7919              655  ,
#        cnt  season mnth     holiday weekday      workingday weathersit  \
#  228  4694    FALL  AUG  NO HOLIDAY     WED     WORKING DAY       GOOD
#  316  3717  WINTER  NOV  NO HOLIDAY     SUN  NO WORKING DAY       GOOD
#
#                                          temp  \
#  228                                  25.9967
#  316                                  12.7192
#
#                                           hum  \
#  228                                  57.5417
#  316                                  45.8333
#
#                                     windspeed  days_since_2011
#  228                                   9.6257              228
#  316                                  18.8753              316  ]

# %% [markdown]
# ### Now bagging

# %% [markdown]
# ### Boosting

# %% [markdown]
# ### Stacking

# %% [markdown]
# # Superseded Code:

# %%
def boostrap_diy(input_df, n_bootstrap, n_sample, random_state=None):
    """
    This function performs bootstrap sampling on a pandas dataframe.

    ------------------------------
    Parameters
    ----------
    input_df : pandas dataframe
        The input dataframe.

    n_bootstrap : int
        The number of bootstrap samples.

    n_sample : int
        The number of samples in each bootstrap sample.

    random_state : int
        The random seed.

    ------------------------------
    Returns
    -------
    bootstrap_samples : list of DataFrames
        List containing the bootstrap samples.
    """
    if random_state is not None:
        np.random.seed(random_state)

    bootstrap_samples = []
    n_rows = input_df.shape[0]

    for _ in range(n_bootstrap):
        # Generate random indices for the bootstrap sample
        random_indices = np.random.randint(0, n_rows, size=n_sample)
        # Select rows corresponding to the random indices
        sample = input_df.iloc[random_indices]
        bootstrap_samples.append(sample)

    return bootstrap_samples
